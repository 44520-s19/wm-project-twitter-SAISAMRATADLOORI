# %%
import tweepy
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
import pickle

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

public_tweets = api.user_timeline('Cristiano')

with open('cristiano.pkl', 'wb') as f:
    pickle.dump(public_tweets, f)

# %%
import pickle
#first twitter account

with open('cristiano.pkl', 'rb') as f:
    public_tweets = pickle.load(f)

print(public_tweets)
# Out:
# [Status(_json={'created_at': 'Mon Jun 17 08:52:46 +0000 2019', 'id': 1140542793481379840, 'id_str': '1140542793481379840', 'text': 'Muitos parabéns, filho! 🎂🎉🎊\nQue continues a ser o lindo menino que tens sido até hoje, o papá tem muito orgulho em… https://t.co/57dXHWhWW1', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/57dXHWhWW1', 'expanded_url': 'https://twitter.com/i/web/status/1140542793481379840', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 155659213, 'id_str': '155659213', 'name': 'Cristiano Ronaldo', 'screen_name': 'Cristiano', 'location': 'Turim, Piemonte', 'description': 'This Privacy Policy addresses the collect
# ...

# %%
#second account
import tweepy
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
import pickle

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

public_tweets = api.user_timeline('WeAreMessi')

with open('WeAreMessi.pkl', 'wb') as f:
    pickle.dump(public_tweets, f)

# %%
import pickle

with open('WeAreMessi.pkl', 'rb') as f:
    public_tweets = pickle.load(f)

print(public_tweets)
# Out:
# [Status(_json={'created_at': 'Mon Jun 17 21:17:58 +0000 2019', 'id': 1140730325905170436, 'id_str': '1140730325905170436', 'text': 'Ig Messi: https://t.co/szGNAde0oM', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1140730317675925505, 'id_str': '1140730317675925505', 'indices': [10, 33], 'media_url': 'http://pbs.twimg.com/media/D9SwLhmXkAE3lOp.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D9SwLhmXkAE3lOp.jpg', 'url': 'https://t.co/szGNAde0oM', 'display_url': 'pic.twitter.com/szGNAde0oM', 'expanded_url': 'https://twitter.com/WeAreMessi/status/1140730325905170436/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 551, 'h': 680, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 827, 'h': 1021, 'resize': 'fit'}, 'medium': {'w': 827, 'h': 1021, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1140730317675925505, 'id_str': '1140730317675925505', 'indices': [10, 33], 'me
# ...

# %%
#third account
import tweepy
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
import pickle

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

public_tweets = api.user_timeline('Ibra_official')

with open('Ibra_official.pkl', 'wb') as f:
    pickle.dump(public_tweets, f)

# %%
import pickle

with open('Ibra_official.pkl', 'rb') as f:
    public_tweets = pickle.load(f)

print(public_tweets)
# Out:
# [Status(_json={'created_at': 'Sun Jun 16 01:41:37 +0000 2019', 'id': 1140071903379353600, 'id_str': '1140071903379353600', 'text': 'Hard work pays off: @svenskfotboll @Malmo_FF @AFCAjax @juventusfc @Inter @FCBarcelona @acmilan @PSG_English @ManUtd… https://t.co/8uBDRYXES3', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'svenskfotboll', 'name': 'Svensk Fotboll', 'id': 1037977200656609281, 'id_str': '1037977200656609281', 'indices': [20, 34]}, {'screen_name': 'Malmo_FF', 'name': 'Malmö FF', 'id': 106721780, 'id_str': '106721780', 'indices': [35, 44]}, {'screen_name': 'AFCAjax', 'name': 'AFC Ajax', 'id': 153000691, 'id_str': '153000691', 'indices': [45, 53]}, {'screen_name': 'juventusfc', 'name': 'JuventusFC', 'id': 253508662, 'id_str': '253508662', 'indices': [54, 65]}, {'screen_name': 'Inter', 'name': 'Inter', 'id': 124450567, 'id_str': '124450567', 'indices': [66, 72]}, {'screen_name': 'FCBarcelona', 'name': 'FC Barcelona', 'id': 969
# ...
