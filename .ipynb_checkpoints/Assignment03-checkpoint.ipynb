# %% [markdown]
# # Twitter Differentiation Assignment
#
# ## SAI SAMRAT ADLOORI:
#
# In this assignment we will be analyzing the tweets  made by 3 football players:
#
# 1. Cristiano Ronaldo (@Cristiano)
# 2. Messi (@WeAreMessi)
# 3. Ibramohivic (@Ibra_official)

# %% [markdown]
# ## Retrieving information from Twitter and storing the tweets into a pickle file

# %%
import tweepy
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
import pickle

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)
#first account
cr7_tweets = api.user_timeline('Cristiano')
with open('cristiano.pkl', 'wb') as f:
    pickle.dump(cr7_tweets, f)
    
#second account
leo_tweets_1 = api.user_timeline('WeAreMessi')
with open('WeAreMessi.pkl', 'wb') as f:
    pickle.dump(leo_tweets, f)
    
#third account
ibra_tweets_2 = api.user_timeline('Ibra_official')
with open('Ibra_official.pkl', 'wb') as f:
    pickle.dump(ibra_tweets, f)

# %% [markdown]
# ## Loading cached data from pickle file

# %%
import pickle
#first twitter account

with open('cristiano.pkl', 'rb') as f:
    cr7_tweets = pickle.load(f)
print(cr7_tweets)

#second account
with open('WeAreMessi.pkl', 'rb') as f:
    leo_tweets = pickle.load(f)
print(leo_tweets)

#third account
with open('Ibra_official.pkl', 'rb') as f:
    ibra_tweets = pickle.load(f)
print(ibra_tweets)
# Out:
# [Status(_json={'created_at': 'Wed Jun 19 10:14:52 +0000 2019', 'id': 1141288228189802496, 'id_str': '1141288228189802496', 'text': "let's go 🚁 👪❤️ https://t.co/Zfe9WM9jHl", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1141288213090394112, 'id_str': '1141288213090394112', 'indices': [15, 38], 'media_url': 'http://pbs.twimg.com/media/D9arlT-X4AAgi36.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D9arlT-X4AAgi36.jpg', 'url': 'https://t.co/Zfe9WM9jHl', 'display_url': 'pic.twitter.com/Zfe9WM9jHl', 'expanded_url': 'https://twitter.com/Cristiano/status/1141288228189802496/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 505, 'resize': 'fit'}, 'large': {'w': 750, 'h': 557, 'resize': 'fit'}, 'medium': {'w': 750, 'h': 557, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1141288213090394112, 'id_str': '1141288213090394112', 'indices': [15, 38], '
# ...

# %%
tweet = public_tweets[0]
print(tweet.text)
tokens = tweet.text.split()
print(tokens)
print(len(tokens))
lower_tokens = [s.lower() for s in tokens]
print(lower_tokens)
unique_lower = set(lower_tokens)
print(unique_lower)
print('Lexical Diversity:', len(unique_lower)/len(lower_tokens))
# Out:
# let's go 🚁 👪❤️ https://t.co/Zfe9WM9jHl
# ["let's", 'go', '🚁', '👪❤️', 'https://t.co/Zfe9WM9jHl']
# 5
# ["let's", 'go', '🚁', '👪❤️', 'https://t.co/zfe9wm9jhl']
# {'go', '👪❤️', 'https://t.co/zfe9wm9jhl', '🚁', "let's"}
# Lexical Diversity: 1.0

# %% [markdown]
# # Average number of words
# Here we are calculating the average number of words for individual football players.
#
# We will take all tweets and calculate the number of words for each tweet of an account. Then we will calculate the average of the number of words we got for each account.

# %%
def word_length(text):
    tokens = text.lower().split()
    return len(tokens)

def calc_avg(words):
    return sum(words)/len(words)

# %%
cristianoWords_Length = []
for tweet in cr7_tweets:
    cristianoWords_Length.append(word_length(tweet.text))
    
messiWords_Length = []
for tweet in leo_tweets:
    messiWords_Length.append(word_length(tweet.text))
    
ibramohivicWords_Length = []
for tweet in ibra_tweets:
    ibramohivicWords_Length.append(word_length(tweet.text))

avgOfWords = {'cristiano Tweets':calc_avg(cristianoWords_Length),'messi Tweets':calc_avg(messiWords_Length),'ibramohivic Tweets':calc_avg(ibramohivicWords_Length)}
print(avgOfWords)
# Out:
# {'cristiano Tweets': 12.75, 'messi Tweets': 5.65, 'ibramohivic Tweets': 9.5}

# %%
import matplotlib.pyplot as plt
heights = list(avgOfWords.values())
heights.sort(reverse=True)
plt.bar(range(len(heights)),heights)
plt.title('Average number of words ')
plt.ylabel('# number of words')
keys = list(avgOfWords.keys())
keys.sort(reverse=True, key=lambda x: avgOfWords[x])
plt.xticks(range(len(keys)),keys)
plt.show()

# %% [markdown]
# # Conclusion:
#
# 1) By the above bar graph, we can conclude that @Cristiano used highest number of words in a tweet that @WeAreMessi and @Ibra_official.
#
# 2) @Cristiano has highest average number of words used with count of 12.75
#
# 3) @WeAreMessi has lowest average number of words used with count of 5.65
#
# 4) @Ibra_official has an average of words used are 9.5
